# %%
import pandas as pd

# %%
df_film = pd.read_csv("df_film.csv")
# Out:
# C:\Users\Luna\AppData\Local\Temp\ipykernel_14404\3587582784.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_film = pd.read_csv("df_film.csv")

# %%
df_film.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0    id_film type_film                   titre  \
# 0             0           0  tt0000001     short              Carmencita
# 1             1           1  tt0000002     short  Le clown et ses chiens
# 2             2           2  tt0000003     short          Pauvre Pierrot
# 3             3           3  tt0000004     short             Un bon bock
# 4             4           4  tt0000005     short        Blacksmith Scene
#
#   année temps_minutes                     genre  note  nb_votes  \
# 0  1894             1         Documentary,Short   5.7    2099.0
# 1  1892             5           Animation,Short   5.6     282.0
# 2  1892             5  Animation,Comedy,Romance   6.5    2117.0
# 3  1892            12           Animation,Short   5.4     182.0
# 4  1893             1              Comedy,Short   6.2    2849.0
#
#         nom_realisateur                   liste_acteurs  \
# 0  William K.L. Dickson                             NaN
# ...

# %% [markdown]
# ## Premier filtre

# %% [markdown]
# ### Garder que les movies

# %%
df_film = df_film.loc[df_film["type_film"]=='movie']

# %% [markdown]
# ### Grader les films après les années 1950

# %%
#df_film = df_film.loc[df_film['année'] > 1950]

# %%
df_film.replace('\\N', "pd.NA")
# Out:
#          Unnamed: 0.1  Unnamed: 0    id_film type_film  \
# 6                   6           8  tt0000009     movie
# 133               133         146  tt0000147     movie
# 292               292         501  tt0000502     movie
# 318               318         573  tt0000574     movie
# 324               324         590  tt0000591     movie
# ...               ...         ...        ...       ...
# 1046297       1046297    11420782  tt9916362     movie
# 1046301       1046301    11420814  tt9916428     movie
# 1046307       1046307    11420866  tt9916538     movie
# 1046318       1046318    11420946  tt9916706     movie
# 1046320       1046320    11420956  tt9916730     movie
#
#                                  titre année temps_minutes  \
# 6                           Miss Jerry  1894            45
# 133      The Corbett-Fitzsimmons Fight  1897           100
# 292                           Bohemios  1905           100
# 318        The Story of the Kelly Gang  1906            70
# ...

# %%
df_film["année"] = df_film["année"].replace('\\N', 0).astype(int)

# %%
df_film.to_csv("df_film.csv")
